# %%
import xgboost as xgb
# Imports
import numpy as np
import os
import pandas as pd
from utils.utilities import *
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Preparo i dati
feat_names = pd.read_csv("./UCIHAR/features.txt", sep=" ", names=["code","feature"])

# Converto i codici (0,1,2,3,4...) in (f0,f1,f2,f3,f4,...)
feat_names["code"] = ["f"+str(code) for _,code in enumerate(feat_names["code"])]

# Numero di features (561)
n_feats = feat_names["code"].size

#feat_names

# Load train data
X_train = pd.read_table('./UCIHAR/train/X_train.txt', delim_whitespace=True, names=["f"+str(code_number+1) for code_number in range(n_feats)])
y_train = pd.read_table('./UCIHAR/train/y_train.txt', delim_whitespace=True, names=["label"])

# Load test data
X_test = pd.read_table('./UCIHAR/test/X_test.txt', delim_whitespace=True, names=["f"+str(code_number+1) for code_number in range(n_feats)])
y_test = pd.read_table('./UCIHAR/test/y_test.txt', delim_whitespace=True, names=["label"])

X_train["is.train"] = 1
X_test["is.train"] = 0

# Concateno i due dataset
X_full = pd.concat([X_train, X_test], keys=['train', 'test'])


# Standardizzo i valori
from sklearn.preprocessing import StandardScaler

#definisco una maschera per selezionare solo le "features" (f1 -> f561)
feat_mask = ["f"+str(code_number+1) for code_number in range(n_feats)]
X_full[feat_mask] = StandardScaler().fit_transform(X_full[feat_mask])


n_feats = n_feats+1

X_tr = X_full.loc['train']
X_test = X_full.loc['test']
# XGboost wants levels to start with 0
y_train["label"] = [int(y_train["label"].iloc[row]-1) for row in range(y_train.size)]
y_test["label"] = [int(y_test["label"].iloc[row]-1) for row in range(y_test.size)]
# Out:
# /home/gabriele/anaconda3/envs/TestEnv/lib/python3.6/site-packages/ipykernel_launcher.py:13: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   del sys.path[0]
# /home/gabriele/anaconda3/envs/TestEnv/lib/python3.6/site-packages/ipykernel_launcher.py:14: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#
# /home/gabriele/anaconda3/envs/TestEnv/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /home/gabriele/anaconda3/envs/TestEnv/lib/python3.6/site-packages/ipykernel_launcher.py:18: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.

# %%
#y_train = [val-1 for _,val in enumerate(y_train)]
#y_test = [val-1 for _,val in enumerate(y_test)]


y_train.label = y_train.label.astype(int)
y_test.label = y_test.label.astype(int)



# XGB style matrices
dtrain = xgb.DMatrix(X_tr, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)
watchlist = {'train': dtrain, 'test': dtest}

# %%
from pandas import DataFrame

grid = {'eta': [0.3,0.5,0.7,0.3,0.5,0.7,0.3,0.5,0.7,0.3,0.5,0.7],
        'max_depth': [1,1,1,2,2,2,6,6,6,8,8,8,]
        }

cv_result = DataFrame(grid, columns= ['eta', 'max_depth'])
cv_result['nrounds'] = 0
cv_result['mll_train'] = 0
cv_result['mll_test'] = 0
cv_result
# Out:
#     eta  max_depth  nrounds  mll_train  mll_test
# 0   0.3          1        0          0         0
# 1   0.5          1        0          0         0
# 2   0.7          1        0          0         0
# 3   0.3          2        0          0         0
# 4   0.5          2        0          0         0
# 5   0.7          2        0          0         0
# 6   0.3          6        0          0         0
# 7   0.5          6        0          0         0
# 8   0.7          6        0          0         0
# 9   0.3          8        0          0         0
# 10  0.5          8        0          0         0
# 11  0.7          8        0          0         0

# %%
# Loop over hyperparameters
#for ind in range(len(cv_result)):
#    print(ind+1)

# %%
# Best Model Params
params = {}
params['booster'] = 'gbtree'
params['eval_metric'] = 'mlogloss'
params['objective'] =  'multi:softprob'
params['eta'] =  0.50
params['max_depth'] =  2
params['gamma'] =  0.0
params['min_child_weight'] =  0
params['colsample_bytree'] =  0.2
params['subsample'] =  1
params['num_class'] = 6
evallist = [(dtest, 'eval'), (dtrain, 'train')]


num_round = 499
bst = xgb.train(params, dtrain, num_round, evallist)
# Out:
# [0]	eval-mlogloss:1.06839	train-mlogloss:0.970493
# [1]	eval-mlogloss:0.808269	train-mlogloss:0.676923
# [2]	eval-mlogloss:0.64673	train-mlogloss:0.506609
# [3]	eval-mlogloss:0.538737	train-mlogloss:0.401013
# [4]	eval-mlogloss:0.466092	train-mlogloss:0.328126
# [5]	eval-mlogloss:0.417114	train-mlogloss:0.279524
# [6]	eval-mlogloss:0.371277	train-mlogloss:0.238161
# [7]	eval-mlogloss:0.347702	train-mlogloss:0.207056
# [8]	eval-mlogloss:0.315556	train-mlogloss:0.179926
# [9]	eval-mlogloss:0.292729	train-mlogloss:0.158955
# [10]	eval-mlogloss:0.274903	train-mlogloss:0.139692
# [11]	eval-mlogloss:0.256199	train-mlogloss:0.124811
# [12]	eval-mlogloss:0.242569	train-mlogloss:0.111666
# [13]	eval-mlogloss:0.226805	train-mlogloss:0.101064
# [14]	eval-mlogloss:0.219187	train-mlogloss:0.092486
# [15]	eval-mlogloss:0.208108	train-mlogloss:0.084112
# [16]	eval-mlogloss:0.202357	train-mlogloss:0.076638
# [17]	eval-mlogloss:0.194766	train-mlogloss:0.071378
# [18]	eval-mlogloss:0.187015	train-mlogloss:0.065845
# [19]	eval-mlogloss:0.180959	train-mlogloss:0.060392
# [20]	eval-mlogloss:0.173322	train-mlogloss:0.056328
# [21]	eval-mlogloss:0.169308	train-mlogloss:0.052183
# [22]	eval-mlogloss:0.165103	train-mlogloss:0.048631
# [23]	eval-mlogloss:0.159321	train-mlogloss:0.045176
# [24]	eval-mlogloss:0.157411	train-mlogloss:0.042526
# [25]	eval-mlogloss:0.155445	train-mlogloss:0.039915
# [26]	eval-mlogloss:0.153903	train-mlogloss:0.037652
# [27]	eval-mlogloss:0.152498	train-mlogloss:0.035189
# [28]	eval-mlogloss:0.150494	train-mlogloss:0.033325
# [29]	eval-mlogloss:0.149323	train-mlogloss:0.03152
# [30]	eval-mlogloss:0.14673	train-mlogloss:0.029921
# [31]	eval-mlogloss:0.144771	train-mlogloss:0.028258
# [32]	eval-mlogloss:0.14426	train-mlogloss:0.026566
# [33]	eval-mlogloss:0.143106	train-mlogloss:0.025385
# [34]	eval-mlogloss:0.140985	train-mlogloss:0.024263
# [35]	eval-mlogloss:0.138983	train-mlogloss:0.022973
# [36]	eval-mlogloss:0.137519	train-mlogloss:0.02168
# [37]	eval-mlogloss:0.13469	train-mlogloss:0.020572
# [38]	eval-mlogloss:0.132122	train-mlogloss:0.019435
# [39]	eval-mlogloss:0.132531	train-mlogloss:0.018696
# [40]	eval-mlogloss:0.131993	train-mlogloss:0.017913
# [41]	eval-mlogloss:0.130889	train-mlogloss:0.017107
# [42]	eval-mlogloss:0.129455	train-mlogloss:0.016437
# [43]	eval-mlogloss:0.127505	train-mlogloss:0.015427
# [44]	eval-mlogloss:0.127849	train-mlogloss:0.01473
# [45]	eval-mlogloss:0.127586	train-mlogloss:0.014054
# [46]	eval-mlogloss:0.128212	train-mlogloss:0.013489
# [47]	eval-mlogloss:0.127565	train-mlogloss:0.01292
# [48]	eval-mlogloss:0.126885	train-mlogloss:0.012429
# [49]	eval-mlogloss:0.126969	train-mlogloss:0.01188
# [50]	eval-mlogloss:0.127397	train-mlogloss:0.011345
# [51]	eval-mlogloss:0.124983	train-mlogloss:0.010848
# [52]	eval-mlogloss:0.127735	train-mlogloss:0.010458
# [53]	eval-mlogloss:0.126031	train-mlogloss:0.010083
# [54]	eval-mlogloss:0.126573	train-mlogloss:0.009628
# [55]	eval-mlogloss:0.126343	train-mlogloss:0.009268
# [56]	eval-mlogloss:0.124179	train-mlogloss:0.008802
# [57]	eval-mlogloss:0.123595	train-mlogloss:0.008415
# [58]	eval-mlogloss:0.123461	train-mlogloss:0.008107
# [59]	eval-mlogloss:0.123408	train-mlogloss:0.007826
# [60]	eval-mlogloss:0.125507	train-mlogloss:0.007441
# [61]	eval-mlogloss:0.12483	train-mlogloss:0.00713
# [62]	eval-mlogloss:0.124841	train-mlogloss:0.0069
# [63]	eval-mlogloss:0.123422	train-mlogloss:0.006636
# [64]	eval-mlogloss:0.124614	train-mlogloss:0.00644
# [65]	eval-mlogloss:0.123662	train-mlogloss:0.006191
# [66]	eval-mlogloss:0.122205	train-mlogloss:0.006017
# [67]	eval-mlogloss:0.122019	train-mlogloss:0.005824
# [68]	eval-mlogloss:0.122884	train-mlogloss:0.00567
# [69]	eval-mlogloss:0.121602	train-mlogloss:0.00546
# [70]	eval-mlogloss:0.120812	train-mlogloss:0.005295
# [71]	eval-mlogloss:0.119292	train-mlogloss:0.005116
# [72]	eval-mlogloss:0.120068	train-mlogloss:0.004961
# [73]	eval-mlogloss:0.120049	train-mlogloss:0.004801
# [74]	eval-mlogloss:0.120288	train-mlogloss:0.004646
# [75]	eval-mlogloss:0.12081	train-mlogloss:0.004493
# [76]	eval-mlogloss:0.120056	train-mlogloss:0.004351
# [77]	eval-mlogloss:0.123072	train-mlogloss:0.004199
# [78]	eval-mlogloss:0.122793	train-mlogloss:0.004081
# [79]	eval-mlogloss:0.121724	train-mlogloss:0.00398
# [80]	eval-mlogloss:0.12208	train-mlogloss:0.00386
# [81]	eval-mlogloss:0.121847	train-mlogloss:0.003705
# [82]	eval-mlogloss:0.121554	train-mlogloss:0.003597
# [83]	eval-mlogloss:0.121993	train-mlogloss:0.003502
# [84]	eval-mlogloss:0.120912	train-mlogloss:0.003356
# [85]	eval-mlogloss:0.120929	train-mlogloss:0.003249
# [86]	eval-mlogloss:0.120353	train-mlogloss:0.003138
# [87]	eval-mlogloss:0.120953	train-mlogloss:0.003042
# [88]	eval-mlogloss:0.119738	train-mlogloss:0.002949
# [89]	eval-mlogloss:0.121482	train-mlogloss:0.002825
# [90]	eval-mlogloss:0.121475	train-mlogloss:0.00272
# [91]	eval-mlogloss:0.121265	train-mlogloss:0.002631
# [92]	eval-mlogloss:0.1212	train-mlogloss:0.002553
# [93]	eval-mlogloss:0.120498	train-mlogloss:0.00245
# [94]	eval-mlogloss:0.12065	train-mlogloss:0.002379
# [95]	eval-mlogloss:0.120701	train-mlogloss:0.002308
# [96]	eval-mlogloss:0.121196	train-mlogloss:0.002248
# [97]	eval-mlogloss:0.121826	train-mlogloss:0.002203
# [98]	eval-mlogloss:0.121618	train-mlogloss:0.00214
# [99]	eval-mlogloss:0.120942	train-mlogloss:0.002084
# [100]	eval-mlogloss:0.121118	train-mlogloss:0.002036
# [101]	eval-mlogloss:0.121313	train-mlogloss:0.001939
# [102]	eval-mlogloss:0.120916	train-mlogloss:0.001875
# [103]	eval-mlogloss:0.120083	train-mlogloss:0.001823
# [104]	eval-mlogloss:0.121416	train-mlogloss:0.001771
# [105]	eval-mlogloss:0.121441	train-mlogloss:0.001723
# [106]	eval-mlogloss:0.121026	train-mlogloss:0.001684
# [107]	eval-mlogloss:0.120034	train-mlogloss:0.001647
# [108]	eval-mlogloss:0.120683	train-mlogloss:0.001597
# [109]	eval-mlogloss:0.121159	train-mlogloss:0.001552
# [110]	eval-mlogloss:0.120879	train-mlogloss:0.001494
# [111]	eval-mlogloss:0.120628	train-mlogloss:0.001458
# [112]	eval-mlogloss:0.12057	train-mlogloss:0.001421
# [113]	eval-mlogloss:0.120082	train-mlogloss:0.001391
# [114]	eval-mlogloss:0.120607	train-mlogloss:0.001359
# [115]	eval-mlogloss:0.120359	train-mlogloss:0.001324
# [116]	eval-mlogloss:0.121264	train-mlogloss:0.001293
# [117]	eval-mlogloss:0.120494	train-mlogloss:0.001254
# [118]	eval-mlogloss:0.121439	train-mlogloss:0.001229
# [119]	eval-mlogloss:0.120715	train-mlogloss:0.001202
# [120]	eval-mlogloss:0.121146	train-mlogloss:0.001176
# [121]	eval-mlogloss:0.120949	train-mlogloss:0.001152
# [122]	eval-mlogloss:0.120485	train-mlogloss:0.001126
# [123]	eval-mlogloss:0.121256	train-mlogloss:0.001104
# [124]	eval-mlogloss:0.121656	train-mlogloss:0.001073
# [125]	eval-mlogloss:0.121836	train-mlogloss:0.001044
# [126]	eval-mlogloss:0.121424	train-mlogloss:0.001016
# [127]	eval-mlogloss:0.121412	train-mlogloss:0.00099
# [128]	eval-mlogloss:0.122435	train-mlogloss:0.000967
# [129]	eval-mlogloss:0.121596	train-mlogloss:0.000948
# [130]	eval-mlogloss:0.122346	train-mlogloss:0.00093
# [131]	eval-mlogloss:0.123338	train-mlogloss:0.000911
# [132]	eval-mlogloss:0.122896	train-mlogloss:0.00089
# [133]	eval-mlogloss:0.121825	train-mlogloss:0.000875
# [134]	eval-mlogloss:0.12183	train-mlogloss:0.000856
# [135]	eval-mlogloss:0.122374	train-mlogloss:0.000832
# [136]	eval-mlogloss:0.122814	train-mlogloss:0.000815
# [137]	eval-mlogloss:0.122809	train-mlogloss:0.000796
# [138]	eval-mlogloss:0.122843	train-mlogloss:0.000782
# [139]	eval-mlogloss:0.123037	train-mlogloss:0.000769
# [140]	eval-mlogloss:0.123176	train-mlogloss:0.000753
# [141]	eval-mlogloss:0.123174	train-mlogloss:0.000737
# [142]	eval-mlogloss:0.122766	train-mlogloss:0.000719
# [143]	eval-mlogloss:0.122796	train-mlogloss:0.000706
# [144]	eval-mlogloss:0.122909	train-mlogloss:0.000691
# [145]	eval-mlogloss:0.123109	train-mlogloss:0.000677
# [146]	eval-mlogloss:0.123383	train-mlogloss:0.000665
# [147]	eval-mlogloss:0.123313	train-mlogloss:0.00065
# [148]	eval-mlogloss:0.123617	train-mlogloss:0.000637
# [149]	eval-mlogloss:0.12379	train-mlogloss:0.000626
# [150]	eval-mlogloss:0.123842	train-mlogloss:0.000613
# [151]	eval-mlogloss:0.123271	train-mlogloss:0.000603
# [152]	eval-mlogloss:0.122768	train-mlogloss:0.000592
# [153]	eval-mlogloss:0.121989	train-mlogloss:0.00058
# [154]	eval-mlogloss:0.122323	train-mlogloss:0.00057
# [155]	eval-mlogloss:0.122952	train-mlogloss:0.000561
# [156]	eval-mlogloss:0.123445	train-mlogloss:0.000549
# [157]	eval-mlogloss:0.122856	train-mlogloss:0.000538
# [158]	eval-mlogloss:0.12356	train-mlogloss:0.00053
# [159]	eval-mlogloss:0.123945	train-mlogloss:0.000522
# [160]	eval-mlogloss:0.123631	train-mlogloss:0.000514
# [161]	eval-mlogloss:0.123436	train-mlogloss:0.000507
# [162]	eval-mlogloss:0.123841	train-mlogloss:0.000498
# [163]	eval-mlogloss:0.123831	train-mlogloss:0.000491
# [164]	eval-mlogloss:0.123794	train-mlogloss:0.000482
# [165]	eval-mlogloss:0.12413	train-mlogloss:0.000475
# [166]	eval-mlogloss:0.124248	train-mlogloss:0.000468
# [167]	eval-mlogloss:0.124502	train-mlogloss:0.000459
# [168]	eval-mlogloss:0.124371	train-mlogloss:0.00045
# [169]	eval-mlogloss:0.125201	train-mlogloss:0.000439
# [170]	eval-mlogloss:0.125129	train-mlogloss:0.000434
# [171]	eval-mlogloss:0.125066	train-mlogloss:0.000426
# [172]	eval-mlogloss:0.124979	train-mlogloss:0.000419
# [173]	eval-mlogloss:0.125074	train-mlogloss:0.000413
# [174]	eval-mlogloss:0.125083	train-mlogloss:0.000406
# [175]	eval-mlogloss:0.125164	train-mlogloss:0.0004
# [176]	eval-mlogloss:0.125388	train-mlogloss:0.000393
# [177]	eval-mlogloss:0.125383	train-mlogloss:0.000388
# [178]	eval-mlogloss:0.12499	train-mlogloss:0.000382
# [179]	eval-mlogloss:0.12505	train-mlogloss:0.000376
# [180]	eval-mlogloss:0.125276	train-mlogloss:0.000371
# [181]	eval-mlogloss:0.125186	train-mlogloss:0.000366
# [182]	eval-mlogloss:0.125375	train-mlogloss:0.000361
# [183]	eval-mlogloss:0.125439	train-mlogloss:0.000357
# [184]	eval-mlogloss:0.12554	train-mlogloss:0.000352
# [185]	eval-mlogloss:0.125271	train-mlogloss:0.000348
# [186]	eval-mlogloss:0.124935	train-mlogloss:0.000343
# [187]	eval-mlogloss:0.125163	train-mlogloss:0.000339
# [188]	eval-mlogloss:0.124883	train-mlogloss:0.000333
# [189]	eval-mlogloss:0.125331	train-mlogloss:0.000329
# [190]	eval-mlogloss:0.125409	train-mlogloss:0.000324
# [191]	eval-mlogloss:0.125826	train-mlogloss:0.000319
# [192]	eval-mlogloss:0.125862	train-mlogloss:0.000314
# [193]	eval-mlogloss:0.12555	train-mlogloss:0.000309
# [194]	eval-mlogloss:0.125488	train-mlogloss:0.000305
# [195]	eval-mlogloss:0.125359	train-mlogloss:0.000302
# [196]	eval-mlogloss:0.125145	train-mlogloss:0.000299
# [197]	eval-mlogloss:0.125522	train-mlogloss:0.000294
# [198]	eval-mlogloss:0.125787	train-mlogloss:0.00029
# [199]	eval-mlogloss:0.12586	train-mlogloss:0.000287
# [200]	eval-mlogloss:0.125786	train-mlogloss:0.000284
# [201]	eval-mlogloss:0.126028	train-mlogloss:0.00028
# [202]	eval-mlogloss:0.125929	train-mlogloss:0.000278
# [203]	eval-mlogloss:0.126054	train-mlogloss:0.000274
# [204]	eval-mlogloss:0.126085	train-mlogloss:0.000271
# [205]	eval-mlogloss:0.126313	train-mlogloss:0.000268
# [206]	eval-mlogloss:0.126354	train-mlogloss:0.000265
# [207]	eval-mlogloss:0.126456	train-mlogloss:0.000262
# [208]	eval-mlogloss:0.126468	train-mlogloss:0.000259
# [209]	eval-mlogloss:0.126679	train-mlogloss:0.000255
# [210]	eval-mlogloss:0.126742	train-mlogloss:0.000252
# [211]	eval-mlogloss:0.126885	train-mlogloss:0.00025
# [212]	eval-mlogloss:0.127006	train-mlogloss:0.000247
# [213]	eval-mlogloss:0.126965	train-mlogloss:0.000245
# [214]	eval-mlogloss:0.126947	train-mlogloss:0.000242
# [215]	eval-mlogloss:0.12746	train-mlogloss:0.000239
# [216]	eval-mlogloss:0.12765	train-mlogloss:0.000236
# [217]	eval-mlogloss:0.127466	train-mlogloss:0.000234
# [218]	eval-mlogloss:0.12747	train-mlogloss:0.000231
# [219]	eval-mlogloss:0.127501	train-mlogloss:0.000229
# [220]	eval-mlogloss:0.12763	train-mlogloss:0.000226
# [221]	eval-mlogloss:0.127445	train-mlogloss:0.000224
# [222]	eval-mlogloss:0.127542	train-mlogloss:0.000222
# [223]	eval-mlogloss:0.127561	train-mlogloss:0.00022
# [224]	eval-mlogloss:0.127597	train-mlogloss:0.000218
# [225]	eval-mlogloss:0.127658	train-mlogloss:0.000216
# [226]	eval-mlogloss:0.12758	train-mlogloss:0.000214
# [227]	eval-mlogloss:0.127649	train-mlogloss:0.000212
# [228]	eval-mlogloss:0.127682	train-mlogloss:0.00021
# [229]	eval-mlogloss:0.127823	train-mlogloss:0.000207
# [230]	eval-mlogloss:0.127773	train-mlogloss:0.000205
# [231]	eval-mlogloss:0.127786	train-mlogloss:0.000204
# [232]	eval-mlogloss:0.1279	train-mlogloss:0.000202
# [233]	eval-mlogloss:0.127522	train-mlogloss:0.0002
# [234]	eval-mlogloss:0.127885	train-mlogloss:0.000198
# [235]	eval-mlogloss:0.128062	train-mlogloss:0.000196
# [236]	eval-mlogloss:0.128137	train-mlogloss:0.000194
# [237]	eval-mlogloss:0.128173	train-mlogloss:0.000192
# [238]	eval-mlogloss:0.128298	train-mlogloss:0.000191
# [239]	eval-mlogloss:0.128372	train-mlogloss:0.000189
# [240]	eval-mlogloss:0.128322	train-mlogloss:0.000188
# [241]	eval-mlogloss:0.128518	train-mlogloss:0.000186
# [242]	eval-mlogloss:0.12889	train-mlogloss:0.000184
# [243]	eval-mlogloss:0.129004	train-mlogloss:0.000182
# [244]	eval-mlogloss:0.128869	train-mlogloss:0.000181
# [245]	eval-mlogloss:0.129145	train-mlogloss:0.000178
# [246]	eval-mlogloss:0.129465	train-mlogloss:0.000177
# [247]	eval-mlogloss:0.12938	train-mlogloss:0.000175
# [248]	eval-mlogloss:0.129167	train-mlogloss:0.000174
# [249]	eval-mlogloss:0.129298	train-mlogloss:0.000172
# [250]	eval-mlogloss:0.12939	train-mlogloss:0.000171
# [251]	eval-mlogloss:0.129637	train-mlogloss:0.000169
# [252]	eval-mlogloss:0.129192	train-mlogloss:0.000168
# [253]	eval-mlogloss:0.129204	train-mlogloss:0.000166
# [254]	eval-mlogloss:0.129353	train-mlogloss:0.000165
# [255]	eval-mlogloss:0.129747	train-mlogloss:0.000164
# [256]	eval-mlogloss:0.12988	train-mlogloss:0.000162
# [257]	eval-mlogloss:0.130105	train-mlogloss:0.000161
# [258]	eval-mlogloss:0.130071	train-mlogloss:0.000159
# [259]	eval-mlogloss:0.130415	train-mlogloss:0.000158
# [260]	eval-mlogloss:0.130213	train-mlogloss:0.000157
# [261]	eval-mlogloss:0.130211	train-mlogloss:0.000156
# [262]	eval-mlogloss:0.130234	train-mlogloss:0.000154
# [263]	eval-mlogloss:0.130355	train-mlogloss:0.000153
# [264]	eval-mlogloss:0.130742	train-mlogloss:0.000152
# [265]	eval-mlogloss:0.130598	train-mlogloss:0.000151
# [266]	eval-mlogloss:0.130857	train-mlogloss:0.000149
# [267]	eval-mlogloss:0.130812	train-mlogloss:0.000148
# [268]	eval-mlogloss:0.130943	train-mlogloss:0.000147
# [269]	eval-mlogloss:0.130648	train-mlogloss:0.000146
# [270]	eval-mlogloss:0.130995	train-mlogloss:0.000145
# [271]	eval-mlogloss:0.130962	train-mlogloss:0.000144
# [272]	eval-mlogloss:0.130985	train-mlogloss:0.000143
# [273]	eval-mlogloss:0.130746	train-mlogloss:0.000141
# [274]	eval-mlogloss:0.130713	train-mlogloss:0.00014
# [275]	eval-mlogloss:0.130819	train-mlogloss:0.000139
# [276]	eval-mlogloss:0.130932	train-mlogloss:0.000138
# [277]	eval-mlogloss:0.131034	train-mlogloss:0.000137
# [278]	eval-mlogloss:0.130919	train-mlogloss:0.000136
# [279]	eval-mlogloss:0.131057	train-mlogloss:0.000135
# [280]	eval-mlogloss:0.131117	train-mlogloss:0.000134
# [281]	eval-mlogloss:0.131328	train-mlogloss:0.000133
# [282]	eval-mlogloss:0.131398	train-mlogloss:0.000132
# [283]	eval-mlogloss:0.131191	train-mlogloss:0.000131
# [284]	eval-mlogloss:0.131088	train-mlogloss:0.00013
# [285]	eval-mlogloss:0.131092	train-mlogloss:0.000129
# [286]	eval-mlogloss:0.131135	train-mlogloss:0.000128
# [287]	eval-mlogloss:0.131496	train-mlogloss:0.000127
# [288]	eval-mlogloss:0.131469	train-mlogloss:0.000126
# [289]	eval-mlogloss:0.131535	train-mlogloss:0.000125
# [290]	eval-mlogloss:0.131469	train-mlogloss:0.000125
# [291]	eval-mlogloss:0.131529	train-mlogloss:0.000124
# [292]	eval-mlogloss:0.131507	train-mlogloss:0.000123
# [293]	eval-mlogloss:0.13148	train-mlogloss:0.000122
# [294]	eval-mlogloss:0.131622	train-mlogloss:0.000121
# [295]	eval-mlogloss:0.131488	train-mlogloss:0.00012
# [296]	eval-mlogloss:0.131604	train-mlogloss:0.00012
# [297]	eval-mlogloss:0.131572	train-mlogloss:0.000119
# [298]	eval-mlogloss:0.131719	train-mlogloss:0.000118
# [299]	eval-mlogloss:0.131705	train-mlogloss:0.000117
# [300]	eval-mlogloss:0.131764	train-mlogloss:0.000116
# [301]	eval-mlogloss:0.131782	train-mlogloss:0.000116
# [302]	eval-mlogloss:0.131686	train-mlogloss:0.000115
# [303]	eval-mlogloss:0.131577	train-mlogloss:0.000114
# [304]	eval-mlogloss:0.131887	train-mlogloss:0.000113
# [305]	eval-mlogloss:0.132153	train-mlogloss:0.000113
# [306]	eval-mlogloss:0.132128	train-mlogloss:0.000112
# [307]	eval-mlogloss:0.13216	train-mlogloss:0.000111
# [308]	eval-mlogloss:0.132009	train-mlogloss:0.000111
# [309]	eval-mlogloss:0.132318	train-mlogloss:0.00011
# [310]	eval-mlogloss:0.132443	train-mlogloss:0.000109
# [311]	eval-mlogloss:0.13213	train-mlogloss:0.000108
# [312]	eval-mlogloss:0.132199	train-mlogloss:0.000108
# [313]	eval-mlogloss:0.132124	train-mlogloss:0.000107
# [314]	eval-mlogloss:0.132086	train-mlogloss:0.000106
# [315]	eval-mlogloss:0.132232	train-mlogloss:0.000106
# [316]	eval-mlogloss:0.132224	train-mlogloss:0.000105
# [317]	eval-mlogloss:0.132251	train-mlogloss:0.000104
# [318]	eval-mlogloss:0.132414	train-mlogloss:0.000104
# [319]	eval-mlogloss:0.132325	train-mlogloss:0.000103
# [320]	eval-mlogloss:0.132473	train-mlogloss:0.000103
# [321]	eval-mlogloss:0.132437	train-mlogloss:0.000102
# [322]	eval-mlogloss:0.132532	train-mlogloss:0.000101
# [323]	eval-mlogloss:0.132601	train-mlogloss:0.000101
# [324]	eval-mlogloss:0.132373	train-mlogloss:0.0001
# [325]	eval-mlogloss:0.13243	train-mlogloss:0.0001
# [326]	eval-mlogloss:0.132468	train-mlogloss:9.9e-05
# [327]	eval-mlogloss:0.132657	train-mlogloss:9.9e-05
# [328]	eval-mlogloss:0.132625	train-mlogloss:9.8e-05
# [329]	eval-mlogloss:0.132625	train-mlogloss:9.7e-05
# [330]	eval-mlogloss:0.132611	train-mlogloss:9.7e-05
# [331]	eval-mlogloss:0.132793	train-mlogloss:9.6e-05
# [332]	eval-mlogloss:0.132711	train-mlogloss:9.6e-05
# [333]	eval-mlogloss:0.132501	train-mlogloss:9.5e-05
# [334]	eval-mlogloss:0.132502	train-mlogloss:9.5e-05
# [335]	eval-mlogloss:0.132425	train-mlogloss:9.4e-05
# [336]	eval-mlogloss:0.132471	train-mlogloss:9.4e-05
# [337]	eval-mlogloss:0.13268	train-mlogloss:9.3e-05
# [338]	eval-mlogloss:0.132673	train-mlogloss:9.3e-05
# [339]	eval-mlogloss:0.13261	train-mlogloss:9.2e-05
# [340]	eval-mlogloss:0.132624	train-mlogloss:9.2e-05
# [341]	eval-mlogloss:0.132444	train-mlogloss:9.1e-05
# [342]	eval-mlogloss:0.132554	train-mlogloss:9.1e-05
# [343]	eval-mlogloss:0.132433	train-mlogloss:9e-05
# [344]	eval-mlogloss:0.132613	train-mlogloss:9e-05
# [345]	eval-mlogloss:0.13269	train-mlogloss:8.9e-05
# [346]	eval-mlogloss:0.132678	train-mlogloss:8.9e-05
# [347]	eval-mlogloss:0.132808	train-mlogloss:8.8e-05
# [348]	eval-mlogloss:0.132633	train-mlogloss:8.8e-05
# [349]	eval-mlogloss:0.132628	train-mlogloss:8.8e-05
# [350]	eval-mlogloss:0.132758	train-mlogloss:8.7e-05
# [351]	eval-mlogloss:0.133016	train-mlogloss:8.7e-05
# [352]	eval-mlogloss:0.13319	train-mlogloss:8.6e-05
# [353]	eval-mlogloss:0.133169	train-mlogloss:8.6e-05
# [354]	eval-mlogloss:0.133178	train-mlogloss:8.5e-05
# [355]	eval-mlogloss:0.133107	train-mlogloss:8.5e-05
# [356]	eval-mlogloss:0.133167	train-mlogloss:8.5e-05
# [357]	eval-mlogloss:0.133223	train-mlogloss:8.4e-05
# [358]	eval-mlogloss:0.13321	train-mlogloss:8.4e-05
# [359]	eval-mlogloss:0.133178	train-mlogloss:8.3e-05
# [360]	eval-mlogloss:0.133244	train-mlogloss:8.3e-05
# [361]	eval-mlogloss:0.133222	train-mlogloss:8.3e-05
# [362]	eval-mlogloss:0.133261	train-mlogloss:8.2e-05
# [363]	eval-mlogloss:0.133478	train-mlogloss:8.2e-05
# [364]	eval-mlogloss:0.133447	train-mlogloss:8.1e-05
# [365]	eval-mlogloss:0.133514	train-mlogloss:8.1e-05
# [366]	eval-mlogloss:0.133591	train-mlogloss:8.1e-05
# [367]	eval-mlogloss:0.133535	train-mlogloss:8e-05
# [368]	eval-mlogloss:0.133556	train-mlogloss:8e-05
# [369]	eval-mlogloss:0.133581	train-mlogloss:7.9e-05
# [370]	eval-mlogloss:0.133516	train-mlogloss:7.9e-05
# [371]	eval-mlogloss:0.133529	train-mlogloss:7.9e-05
# [372]	eval-mlogloss:0.133623	train-mlogloss:7.8e-05
# [373]	eval-mlogloss:0.133522	train-mlogloss:7.8e-05
# [374]	eval-mlogloss:0.133655	train-mlogloss:7.8e-05
# [375]	eval-mlogloss:0.133527	train-mlogloss:7.7e-05
# [376]	eval-mlogloss:0.133633	train-mlogloss:7.7e-05
# [377]	eval-mlogloss:0.133848	train-mlogloss:7.7e-05
# [378]	eval-mlogloss:0.133878	train-mlogloss:7.6e-05
# [379]	eval-mlogloss:0.133818	train-mlogloss:7.6e-05
# [380]	eval-mlogloss:0.133918	train-mlogloss:7.6e-05
# [381]	eval-mlogloss:0.134138	train-mlogloss:7.5e-05
# [382]	eval-mlogloss:0.134222	train-mlogloss:7.5e-05
# [383]	eval-mlogloss:0.134295	train-mlogloss:7.5e-05
# [384]	eval-mlogloss:0.134421	train-mlogloss:7.4e-05
# [385]	eval-mlogloss:0.134448	train-mlogloss:7.4e-05
# [386]	eval-mlogloss:0.134356	train-mlogloss:7.4e-05
# [387]	eval-mlogloss:0.134393	train-mlogloss:7.3e-05
# [388]	eval-mlogloss:0.134496	train-mlogloss:7.3e-05
# [389]	eval-mlogloss:0.134532	train-mlogloss:7.3e-05
# [390]	eval-mlogloss:0.134591	train-mlogloss:7.2e-05
# [391]	eval-mlogloss:0.134596	train-mlogloss:7.2e-05
# [392]	eval-mlogloss:0.134663	train-mlogloss:7.2e-05
# [393]	eval-mlogloss:0.134609	train-mlogloss:7.1e-05
# [394]	eval-mlogloss:0.13478	train-mlogloss:7.1e-05
# [395]	eval-mlogloss:0.134806	train-mlogloss:7.1e-05
# [396]	eval-mlogloss:0.134697	train-mlogloss:7e-05
# [397]	eval-mlogloss:0.134667	train-mlogloss:7e-05
# [398]	eval-mlogloss:0.134647	train-mlogloss:7e-05
# [399]	eval-mlogloss:0.134592	train-mlogloss:6.9e-05
# [400]	eval-mlogloss:0.134689	train-mlogloss:6.9e-05
# [401]	eval-mlogloss:0.134795	train-mlogloss:6.9e-05
# [402]	eval-mlogloss:0.134816	train-mlogloss:6.9e-05
# [403]	eval-mlogloss:0.134843	train-mlogloss:6.8e-05
# [404]	eval-mlogloss:0.134918	train-mlogloss:6.8e-05
# [405]	eval-mlogloss:0.134867	train-mlogloss:6.8e-05
# [406]	eval-mlogloss:0.13503	train-mlogloss:6.7e-05
# [407]	eval-mlogloss:0.135184	train-mlogloss:6.7e-05
# [408]	eval-mlogloss:0.135293	train-mlogloss:6.7e-05
# [409]	eval-mlogloss:0.13528	train-mlogloss:6.7e-05
# [410]	eval-mlogloss:0.135394	train-mlogloss:6.6e-05
# [411]	eval-mlogloss:0.13545	train-mlogloss:6.6e-05
# [412]	eval-mlogloss:0.13558	train-mlogloss:6.6e-05
# [413]	eval-mlogloss:0.135468	train-mlogloss:6.6e-05
# [414]	eval-mlogloss:0.135471	train-mlogloss:6.5e-05
# [415]	eval-mlogloss:0.135385	train-mlogloss:6.5e-05
# [416]	eval-mlogloss:0.135513	train-mlogloss:6.5e-05
# [417]	eval-mlogloss:0.135389	train-mlogloss:6.5e-05
# [418]	eval-mlogloss:0.135274	train-mlogloss:6.4e-05
# [419]	eval-mlogloss:0.135315	train-mlogloss:6.4e-05
# [420]	eval-mlogloss:0.135416	train-mlogloss:6.4e-05
# [421]	eval-mlogloss:0.135489	train-mlogloss:6.4e-05
# [422]	eval-mlogloss:0.135479	train-mlogloss:6.3e-05
# [423]	eval-mlogloss:0.135527	train-mlogloss:6.3e-05
# [424]	eval-mlogloss:0.135586	train-mlogloss:6.3e-05
# [425]	eval-mlogloss:0.135702	train-mlogloss:6.3e-05
# [426]	eval-mlogloss:0.135743	train-mlogloss:6.2e-05
# [427]	eval-mlogloss:0.135818	train-mlogloss:6.2e-05
# [428]	eval-mlogloss:0.135865	train-mlogloss:6.2e-05
# [429]	eval-mlogloss:0.135852	train-mlogloss:6.2e-05
# [430]	eval-mlogloss:0.135851	train-mlogloss:6.1e-05
# [431]	eval-mlogloss:0.135759	train-mlogloss:6.1e-05
# [432]	eval-mlogloss:0.135847	train-mlogloss:6.1e-05
# [433]	eval-mlogloss:0.13574	train-mlogloss:6.1e-05
# [434]	eval-mlogloss:0.135896	train-mlogloss:6.1e-05
# [435]	eval-mlogloss:0.136007	train-mlogloss:6e-05
# [436]	eval-mlogloss:0.136022	train-mlogloss:6e-05
# [437]	eval-mlogloss:0.136001	train-mlogloss:6e-05
# [438]	eval-mlogloss:0.135994	train-mlogloss:6e-05
# [439]	eval-mlogloss:0.136063	train-mlogloss:6e-05
# [440]	eval-mlogloss:0.136174	train-mlogloss:5.9e-05
# [441]	eval-mlogloss:0.13616	train-mlogloss:5.9e-05
# [442]	eval-mlogloss:0.136294	train-mlogloss:5.9e-05
# [443]	eval-mlogloss:0.136226	train-mlogloss:5.9e-05
# [444]	eval-mlogloss:0.136249	train-mlogloss:5.8e-05
# [445]	eval-mlogloss:0.136366	train-mlogloss:5.8e-05
# [446]	eval-mlogloss:0.136419	train-mlogloss:5.8e-05
# [447]	eval-mlogloss:0.136453	train-mlogloss:5.8e-05
# [448]	eval-mlogloss:0.136383	train-mlogloss:5.8e-05
# [449]	eval-mlogloss:0.136475	train-mlogloss:5.7e-05
# [450]	eval-mlogloss:0.136405	train-mlogloss:5.7e-05
# [451]	eval-mlogloss:0.136569	train-mlogloss:5.7e-05
# [452]	eval-mlogloss:0.136643	train-mlogloss:5.7e-05
# [453]	eval-mlogloss:0.136639	train-mlogloss:5.7e-05
# [454]	eval-mlogloss:0.136684	train-mlogloss:5.6e-05
# [455]	eval-mlogloss:0.136716	train-mlogloss:5.6e-05
# [456]	eval-mlogloss:0.136671	train-mlogloss:5.6e-05
# [457]	eval-mlogloss:0.13675	train-mlogloss:5.6e-05
# [458]	eval-mlogloss:0.136743	train-mlogloss:5.6e-05
# [459]	eval-mlogloss:0.13674	train-mlogloss:5.5e-05
# [460]	eval-mlogloss:0.136716	train-mlogloss:5.5e-05
# [461]	eval-mlogloss:0.136726	train-mlogloss:5.5e-05
# [462]	eval-mlogloss:0.136784	train-mlogloss:5.5e-05
# [463]	eval-mlogloss:0.136951	train-mlogloss:5.5e-05
# [464]	eval-mlogloss:0.136906	train-mlogloss:5.4e-05
# [465]	eval-mlogloss:0.136989	train-mlogloss:5.4e-05
# [466]	eval-mlogloss:0.13691	train-mlogloss:5.4e-05
# [467]	eval-mlogloss:0.136937	train-mlogloss:5.4e-05
# [468]	eval-mlogloss:0.136982	train-mlogloss:5.4e-05
# [469]	eval-mlogloss:0.137028	train-mlogloss:5.3e-05
# [470]	eval-mlogloss:0.137003	train-mlogloss:5.3e-05
# [471]	eval-mlogloss:0.137077	train-mlogloss:5.3e-05
# [472]	eval-mlogloss:0.137042	train-mlogloss:5.3e-05
# [473]	eval-mlogloss:0.137128	train-mlogloss:5.3e-05
# [474]	eval-mlogloss:0.137126	train-mlogloss:5.3e-05
# [475]	eval-mlogloss:0.137186	train-mlogloss:5.2e-05
# [476]	eval-mlogloss:0.137259	train-mlogloss:5.2e-05
# [477]	eval-mlogloss:0.137428	train-mlogloss:5.2e-05
# [478]	eval-mlogloss:0.137397	train-mlogloss:5.2e-05
# [479]	eval-mlogloss:0.137354	train-mlogloss:5.2e-05
# [480]	eval-mlogloss:0.137493	train-mlogloss:5.2e-05
# [481]	eval-mlogloss:0.137447	train-mlogloss:5.1e-05
# [482]	eval-mlogloss:0.13756	train-mlogloss:5.1e-05
# [483]	eval-mlogloss:0.137571	train-mlogloss:5.1e-05
# [484]	eval-mlogloss:0.137461	train-mlogloss:5.1e-05
# [485]	eval-mlogloss:0.137621	train-mlogloss:5.1e-05
# [486]	eval-mlogloss:0.137584	train-mlogloss:5.1e-05
# [487]	eval-mlogloss:0.137661	train-mlogloss:5.1e-05
# [488]	eval-mlogloss:0.137709	train-mlogloss:5e-05
# [489]	eval-mlogloss:0.137744	train-mlogloss:5e-05
# [490]	eval-mlogloss:0.137994	train-mlogloss:5e-05
# [491]	eval-mlogloss:0.13809	train-mlogloss:5e-05
# [492]	eval-mlogloss:0.13806	train-mlogloss:5e-05
# [493]	eval-mlogloss:0.138121	train-mlogloss:5e-05
# [494]	eval-mlogloss:0.138234	train-mlogloss:4.9e-05
# [495]	eval-mlogloss:0.138194	train-mlogloss:4.9e-05
# [496]	eval-mlogloss:0.13818	train-mlogloss:4.9e-05
# [497]	eval-mlogloss:0.138106	train-mlogloss:4.9e-05
# [498]	eval-mlogloss:0.138028	train-mlogloss:4.9e-05

# %%
# Predict
ypred = bst.predict(dtest)
y_pred = np.argmax(ypred, axis=1)
predicted_df = DataFrame(y_pred, columns= ['label'])

# Accuracy
acc = 100. * np.sum(predicted_df == y_test) / len(y_test)
print("Accuracy: {0:.2f}%".format(acc["label"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d437d938428f> in <module>
#       1 # Predict
# ----> 2 ypred = bst.predict(dtest)
#       3 y_pred = np.argmax(ypred, axis=1)
#       4 predicted_df = DataFrame(y_pred, columns= ['label'])
#       5
#
# NameError: name 'bst' is not defined
